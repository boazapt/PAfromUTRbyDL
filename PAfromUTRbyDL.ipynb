# %% [markdown]
# # Predicting CAI from UTR genome data using deep learning
#
# ---
#
# ![](http://hawaiireedlab.com/gwiki/images/thumb/6/62/Gene-protein-coding.png/800px-Gene-protein-coding.png)
#
# ---

# %% [markdown]
# # GOOGLE DRIVE MOUNT

# %%
# If we want to use the save/load models later, we will have to mount the google drive first.
# We have put the models saved file in the shared directory for case you will need to load them

from google.colab import drive
drive.mount('/GoogleDrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /GoogleDrive

# %% [markdown]
# # Models

# %% [markdown]
# ## Baseline

# %% [markdown]
# ### Data Preprocess - Baseline

# %%
import numpy as np_bl

path = '/GoogleDrive/My Drive/project_0330342797_038628343/data/OurData/'
pathOutput = '/GoogleDrive/My Drive/project_0330342797_038628343/baseline/'
file='data_random_forest_1500_records_from037_to087_for_each_hundretch_of_each_bacteria_75000_Records.npy'
file2 ='data_random_forest_betaFamily_263379.npy'
file3 ='data_random_forest_all_up_to_13_from037_to087_for_each_hundretch_of_each_bacteria_257648_Records.npy'
file1 = 'data_random_forest_all_up_to_13_for_each_hundretch_of_each_bacteria_270274_Records.npy'
dataBL = np_bl.load(path+file)

print(dataBL.shape)
# Out:
# (75000, 51)

# %%
# split data to train, test --> with shuffling

from sklearn.model_selection import train_test_split

dataBL_train, dataBL_test = train_test_split(dataBL,train_size=0.7,test_size=0.3,random_state=42)

# all data
dataBL_all_data = dataBL[:,0:50]
dataBL_all_target = dataBL[:,50]
dataBL_all_target1 = dataBL[:,50]*1000
dataBL_all_target1 = dataBL_all_target1.astype(np_bl.int64)
print('dataBL_all_data.shape',dataBL_all_data.shape)
print('dataBL_all_target.shape',dataBL_all_target.shape)
print('dataBL_all_target1',dataBL_all_target1[1:10])

# train data + target
dataBL_train_data = dataBL_train[:,0:50]
dataBL_train_target = dataBL_train[:,50]
print('dataBL_train_data.shape',dataBL_train_data.shape)
#print('dataBL_train_data',dataBL_train_data[1:10])

dataBL_train_target1 = dataBL_train[:,50]*1000
dataBL_train_target1 = dataBL_train_target1.astype(np_bl.int64)
print('dataBL_train_target1',dataBL_train_target1[1:10])

# test data + target
dataBL_test_data = dataBL_test[:,0:50]
dataBL_test_target = dataBL_test[:,50]
print('dataBL_test_data.shape',dataBL_test_data.shape)
#print('dataBL_test_data',dataBL_test_data[1:10])

dataBL_test_target1 = dataBL_test[:,50]*1000
dataBL_test_target1 = dataBL_test_target1.astype(np_bl.int64)
print('dataBL_test_target1',dataBL_test_target1[1:10])
# Out:
# dataBL_all_data.shape (75000, 50)
# dataBL_all_target.shape (75000,)
# dataBL_all_target1 [383 383 384 378 382 379 380 380 379]
# dataBL_train_data.shape (52500, 50)
# dataBL_train_target1 [833 734 399 637 405 431 832 657 582]
# dataBL_test_data.shape (22500, 50)
# dataBL_test_target1 [392 503 861 775 853 552 377 591 669]

# %% [markdown]
# ### Determine Performance Metrics

# %%
# Calc some baseline metrics
print('Baseline Min Range:', round(np_bl.min(dataBL_train_target1), 2))
print('Baseline Max Range:', round(np_bl.max(dataBL_train_target1), 2))

# Our basic baseline will be the mean of the train dataset
predictions_bl = np_bl.mean(dataBL_train_target1)
print('Baseline Mean/Prediction:', round(np_bl.mean(dataBL_train_target1), 2))

# Calculate the absolute errors
errors_bl = abs(predictions_bl - dataBL_test_target1)
errors_sqrd_bl = errors_bl*errors_bl
mae_bl=round(np_bl.mean(errors_bl), 2)
mse_bl=round(np_bl.mean(errors_sqrd_bl), 2)
rmse_bl=round(np_bl.sqrt(mse_bl), 2)


# Print out the mean absolute error (mae)
print('Baseline Mean Absolute Error:', mae_bl)

# Print out the mean squared error (mse)
print('Baseline Mean Squared Error:', mse_bl)
# Print out the mean squared error (rmse)
print('Baseline Root Mean Squared Error:', rmse_bl)


# Calculate mean absolute percentage error (MAPE)
mape_bl = 100 * (errors_bl / dataBL_test_target1)

#print(mape_bl[1:10])

# Calculate and display accuracy
accuracy_bl = 100 - np_bl.mean(mape_bl)

print('Baseline Accuracy:', round(accuracy_bl, 2), '%.')
# Out:
# Baseline Min Range: 375
# Baseline Max Range: 875
# Baseline Mean/Prediction: 625.11
# Baseline Mean Absolute Error: 123.9
# Baseline Mean Squared Error: 20581.46
# Baseline Root Mean Squared Error: 143.46
# Baseline Accuracy: 78.39 %.

# %%
import matplotlib.pyplot as plt

# An "interface" to matplotlib.axes.Axes.hist() method
n, bins, patches = plt.hist(dataBL_all_target1, bins=1000, color='#0504aa', alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('CAI')
plt.ylabel('Frequency')
plt.title('CAI DATASET HISTOGRAM')
#plt.text(200, 2000, r'$\mu=' + np_bl.str(np_bl.mean(dataBL_all_target1)))
maxfreq = n.max()
# Set a clean upper y-axis limit.
plt.ylim(top=np_bl.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)

# %% [markdown]
# ## Fully Connected

# %% [markdown]
# ### Data Preprocess - Fully Connected

# %%
import numpy as np_fc

path = '/GoogleDrive/My Drive/project_0330342797_038628343/data/OurData/'
pathOutput = '/GoogleDrive/My Drive/project_0330342797_038628343/outputWeights/'
file ='data_NN_1500_records_from038_to088_for_each_hundretch_of_each_bacteria_75000_Records.npy'
file1 ='data_NN_betaFamily_263379.npy'
file2 = 'data_NN_all_up_to_13_for_each_hundretch_of_each_bacteria_270274_Records.npy'
dataFC = np_fc.load(path+file)
print(dataFC.shape)
# Out:
# (75000, 201)

# %%
# split data to train, valid, test --> with shuffling

from sklearn.model_selection import train_test_split

dataFC_train, dataFC_validate = train_test_split(dataFC,train_size=0.7,test_size=0.3, random_state=42)
dataFC_validate, dataFC_test = train_test_split(dataFC_validate,train_size=0.50,test_size=0.50, random_state=42)

# train data + target
dataFC_train_data = dataFC_train[:,0:200]
dataFC_train_target = dataFC_train[:,200]
print('dataFC_train_data.shape:') 
print(dataFC_train_data.shape)

dataFC_train_target1 = dataFC_train[:,200]*1000
dataFC_train_target1 = dataFC_train_target1.astype(np_fc.int64)

print('dataFC_train_target1:') 
print(dataFC_train_target1[1:10])

# validation data + target
dataFC_validate_data = dataFC_validate [:,0:200]
dataFC_validate_target = dataFC_validate[:,200]

dataFC_validate_target1 = dataFC_validate[:,200]*1000
dataFC_validate_target1 = dataFC_validate_target1.astype(np_fc.int64)

print('dataFC_validate_data.shape:') 
print(dataFC_validate_data.shape)

print('dataFC_validate_target1:') 
print(dataFC_validate_target1[1:10])

# test data + target
dataFC_test_data = dataFC_test[:,0:200]
dataFC_test_target = dataFC_test[:,200]

dataFC_test_target1 = dataFC_test[:,200]*1000
dataFC_test_target1 = dataFC_test_target1.astype(np_fc.int64)

print('dataFC_test_data.shape:') 
print(dataFC_test_data.shape)

print('dataFC_test_target1:') 
print(dataFC_test_target1[1:10])
# Out:
# dataFC_train_data.shape:
# (52500, 200)
# dataFC_train_target1:
# [833 734 399 637 405 431 832 657 582]
# dataFC_validate_data.shape:
# (11250, 200)
# dataFC_validate_target1:
# [790 811 717 417 557 793 436 415 460]
# dataFC_test_data.shape:
# (11250, 200)
# dataFC_test_target1:
# [794 521 628 389 383 765 616 778 681]

# %% [markdown]
# ### Load Existing Model - Fully Connected

# %% [markdown]
# ### Train Model - Fully Connected

# %%
from keras.models import Sequential
from keras import models, layers
import keras

# Initiate an empty model
model_fc = Sequential()
model_fc.reset_states()

# Input Layer
model_fc.add(layers.Dense(200, kernel_initializer='random_uniform', bias_initializer='ones', input_dim = dataFC_train_data.shape[1], activation='relu'))
model_fc.add(layers.BatchNormalization())


# Hidden Layers
model_fc.add(layers.Dense(400, kernel_initializer='random_uniform', bias_initializer='ones',activation='relu'))
model_fc.add(layers.BatchNormalization())
model_fc.add(layers.Dense(200, kernel_initializer='random_uniform', bias_initializer='ones',activation='relu'))
model_fc.add(layers.BatchNormalization())
model_fc.add(layers.Dropout(0.5))

# Output Layer
model_fc.add(layers.Dense(1, kernel_initializer='random_uniform',activation='relu'))


model_fc.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 200)               40200
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 200)               800
# _________________________________________________________________
# dense_20 (Dense)             (None, 400)               80400
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 400)               1600
# _________________________________________________________________
# dense_21 (Dense)             (None, 200)               80200
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 200)               800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 201
# =================================================================
# Total params: 204,201
# Trainable params: 202,601
# Non-trainable params: 1,600
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint
from keras import optimizers

# More Params
batch_size_fc = 250
epochs_fc = 100

checkpoint_fc_name = pathOutput+'fullyConnected/Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint_fc = ModelCheckpoint(checkpoint_fc_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_fc_list = [checkpoint_fc]

optimizer_fc = optimizers.Adam(lr=0.001, decay=0.05, amsgrad=False)

# Compile the model
model_fc.reset_states()
model_fc.compile(loss='mse', optimizer='adam', metrics=['mape','mse', 'mse'])

# Train
hist_fc = model_fc.fit(dataFC_train_data, dataFC_train_target1, validation_data=(dataFC_validate_data,dataFC_validate_target1), batch_size=batch_size_fc, epochs=epochs_fc,callbacks=callbacks_fc_list)
# Out:
# Train on 52500 samples, validate on 11250 samples
# Epoch 1/100
# 52500/52500 [==============================] - 4s 73us/step - loss: 388963.6525 - mean_absolute_percentage_error: 96.9941 - mean_squared_error: 388963.6525 - mean_squared_error_1: 388963.6525 - val_loss: 344717.8951 - val_mean_absolute_percentage_error: 90.8794 - val_mean_squared_error: 344717.8951 - val_mean_squared_error_1: 344717.8951
#
# Epoch 00001: val_loss improved from inf to 344717.89514, saving model to /GoogleDrive/My Drive/project_0330342797_038628343/outputWeights/fullyConnected/Weights-001--344717.89514.hdf5
# Epoch 2/100
# 52500/52500 [==============================] - 3s 49us/step - loss: 321959.1063 - mean_absolute_percentage_error: 87.2754 - mean_squared_error: 321959.1063 - mean_squared_error_1: 321959.1063 - val_loss: 245795.4410 - val_mean_absolute_percentage_error: 74.2113 - val_mean_squared_error: 245795.4410 - val_mean_squared_error_1: 245795.4410
#
# Epoch 00002: val_loss improved from 344717.89514 to 245795.44097, saving model to /GoogleDrive/My Drive/project_0330342797_038628343/outputWeights/fullyConnected/Weights-002--245795.44097.hdf5
# Epoch 3/100
# 52500/52500 [==============================] - 3s 49us/step - loss: 233994.2630 - mean_absolute_percentage_error: 71.6985 - mean_squared_error: 233994.2630 - mean_squared_error_1: 233994.2630 - val_loss: 148724.2047 - val_mean_absolute_percentage_error: 51.6896 - val_mean_squared_error: 148724.2047 - val_mean_squared_error_1: 148724.2047
#
# Epoch 00003: val_loss improved from 245795.44097 to 148724.20469, saving model to /GoogleDrive/My Drive/project_0330342797_038628343/outputWeights/fullyConnected/Weights-003--148724.20469.hdf5
# Epoch 4/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 152077.9977 - mean_absolute_percentage_error: 53.4172 - mean_squared_error: 152077.9977 - mean_squared_error_1: 152077.9977 - val_loss: 84531.4622 - val_mean_absolute_percentage_error: 34.5899 - val_mean_squared_error: 84531.4622 - val_mean_squared_error_1: 84531.4622
#
# Epoch 00004: val_loss improved from 148724.20469 to 84531.46215, saving model to /GoogleDrive/My Drive/project_0330342797_038628343/outputWeights/fullyConnected/Weights-004--84531.46215.hdf5
# Epoch 5/100
# 52500/52500 [==============================] - 3s 49us/step - loss: 92939.0485 - mean_absolute_percentage_error: 37.7101 - mean_squared_error: 92939.0485 - mean_squared_error_1: 92939.0485 - val_loss: 55887.4434 - val_mean_absolute_percentage_error: 31.0529 - val_mean_squared_error: 55887.4434 - val_mean_squared_error_1: 55887.4434
#
# Epoch 00005: val_loss improved from 84531.46215 to 55887.44340, saving model to /GoogleDrive/My Drive/project_0330342797_038628343/outputWeights/fullyConnected/Weights-005--55887.44340.hdf5
# Epoch 6/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 57855.5739 - mean_absolute_percentage_error: 28.4460 - mean_squared_error: 57855.5739 - mean_squared_error_1: 57855.5739 - val_loss: 45090.9491 - val_mean_absolute_percentage_error: 30.8878 - val_mean_squared_error: 45090.9491 - val_mean_squared_error_1: 45090.9491
#
# Epoch 00006: val_loss improved from 55887.44340 to 45090.94913, saving model to /GoogleDrive/My Drive/project_0330342797_038628343/outputWeights/fullyConnected/Weights-006--45090.94913.hdf5
# Epoch 7/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 39492.6058 - mean_absolute_percentage_error: 24.1196 - mean_squared_error: 39492.6058 - mean_squared_error_1: 39492.6058 - val_loss: 147369.7783 - val_mean_absolute_percentage_error: 65.4363 - val_mean_squared_error: 147369.7783 - val_mean_squared_error_1: 147369.7783
#
# Epoch 00007: val_loss did not improve from 45090.94913
# Epoch 8/100
# 52500/52500 [==============================] - 3s 48us/step - loss:
#
# Epoch 00022: val_loss did not improve from 18962.34058
# Epoch 23/100
# 52500/52500 [==============================] - 3s 49us/step - loss: 20921.5678 - mean_absolute_percentage_error: 20.8288 - mean_squared_error: 20921.5678 - mean_squared_error_1: 20921.5678 - val_loss: 18970.3381 - val_mean_absolute_percentage_error: 20.4670 - val_mean_squared_error: 18970.3381 - val_mean_squared_error_1: 18970.3381
#
# Epoch 00023: val_loss did not improve from 18962.34058
# Epoch 24/100
# 52500/52500 [==============================] - 3s 49us/step - loss: 20720.3925 - mean_absolute_percentage_error: 20.6457 - mean_squared_error: 20720.3925 - mean_squared_error_1: 20720.3925 - val_loss: 19531.3001 - val_mean_absolute_percentage_error: 20.0553 - val_mean_squared_error: 19531.3001 - val_mean_squared_error_1: 19531.3001
#
# Epoch 00024: val_loss did not improve from 18962.34058
# Epoch 25/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 20522.6198 - mean_absolute_percentage_error: 20.5181 - mean_squared_error: 20522.6198 - mean_squared_error_1: 20522.6198 - val_loss: 19454.3258 - val_mean_absolute_percentage_error: 20.8450 - val_mean_squared_error: 19454.3258 - val_mean_squared_error_1: 19454.3258
#
# Epoch 00025: val_loss did not improve from 18962.34058
# Epoch 26/100
# 52500/52500 [==============================] - 3s 49us/step - loss: 20160.9995 - mean_absolute_percentage_error: 20.3564 - mean_squared_error: 20160.9995 - mean_squared_error_1: 20160.9995 - val_loss: 19626.3302 - val_mean_absolute_percentage_error: 20.4267 - val_mean_squared_error: 19626.3302 - val_mean_squared_error_1: 19626.3302
#
# Epoch 00026: val_loss did not improve from 18962.34058
# Epoch 27/100
# 52500/52500 [==============================] - 3s 49us/step - loss: 19807.6832 - mean_absolute_percentage_error: 20.1051 - mean_squared_error: 19807.6832 - mean_squared_error_1: 19807.6832 - val_loss: 19395.4009 - val_mean_absolute_percentage_error: 20.3981 - val_mean_squared_error: 19395.4009 - val_mean_squared_error_1: 19395.4009
#
# Epoch 00027: val_loss did not improve from 18962.34058
# Epoch 28/100
# 52500/52500 [==============================] - 3s 51us/step - loss: 19559.3790 - mean_absolute_percentage_error: 19.9536 - mean_squared_error: 19559.3790 - mean_squared_error_1: 19559.3790 - val_loss: 19665.7107 - val_mean_absolute_percentage_error: 20.6256 - val_mean_squared_error: 19665.7107 - val_mean_squared_error_1: 19665.7107
#
# Epoch 00028: val_loss did not improve from 18962.34058
# Epoch 29/100
# 52500/52500 [==============================] - 3s 51us/step - loss: 19387.8330 - mean_absolute_percentage_error: 19.8090 - mean_squared_error: 19387.8330 - mean_squared_error_1: 19387.8330 - val_loss: 19894.5263 - val_mean_absolute_percentage_error: 20.7845 - val_mean_squared_error: 19894.5263 - val_mean_squared_error_1: 19894.5263
#
# Epoch 00029: val_loss did not improve from 18962.34058
# Epoch 30/100
# 52500/52500 [==============================] - 3s 51us/step - loss: 19007.1080 - mean_absolute_percentage_error: 19.6292 - mean_squared_error: 19007.1080 - mean_squared_error_1: 19007.1080 - val_loss: 20015.3442 - val_mean_absolute_percentage_error: 20.7512 - val_mean_squared_error: 20015.3442 - val_mean_squared_error_1: 20015.3442
#
# Epoch 00030: val_loss did not improve from 18962.34058
# Epoch 31/100
# 52500/52500 [==============================] - 3s 50us/step - loss: 18816.4614 - mean_absolute_percentage_error: 19.5045 - mean_squared_error: 18816.4614 - mean_squared_error_1: 18816.4614 - val_loss: 20387.0015 - val_mean_absolute_percentage_error: 20.3336 - val_mean_squared_error: 20387.0015 - val_mean_squared_error_1: 20387.0015
#
# Epoch 00031: val_loss did not improve from 18962.34058
# Epoch 32/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 18518.0020 - mean_absolute_percentage_error: 19.3206 - mean_squared_error: 18518.0020 - mean_squared_error_1: 18518.0020 - val_loss: 20141.4441 - val_mean_absolute_percentage_error: 20.7097 - val_mean_squared_error: 20141.4441 - val_mean_squared_error_1: 20141.4441
#
# Epoch 00032: val_loss did not improve from 18962.34058
# Epoch 33/100
# 52500/52500 [==============================] - 2s 48us/step - loss: 18349.1928 - mean_absolute_percentage_error: 19.1847 - mean_squared_error: 18349.1928 - mean_squared_error_1: 18349.1928 - val_loss: 20699.6535 - val_mean_absolute_percentage_error: 21.0705 - val_mean_squared_error: 20699.6535 - val_mean_squared_error_1: 20699.6535
#
# Epoch 00033: val_loss did not improve from 18962.34058
# Epoch 34/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 18108.0400 - mean_absolute_percentage_error: 19.0211 - mean_squared_error: 18108.0400 - mean_squared_error_1: 18108.0400 - val_loss: 20742.2057 - val_mean_absolute_percentage_error: 21.2936 - val_mean_squared_error: 20742.2057 - val_mean_squared_error_1: 20742.2057
#
# Epoch 00034: val_loss did not improve from 18962.34058
# Epoch 35/100
# 52500/52500 [==============================] - 2s 47us/step - loss: 17967.2430 - mean_absolute_percentage_error: 18.9398 - mean_squared_error: 17967.2430 - mean_squared_error_1: 17967.2430 - val_loss: 20674.7496 - val_mean_absolute_percentage_error: 20.6414 - val_mean_squared_error: 20674.7496 - val_mean_squared_error_1: 20674.7496
#
# Epoch 00035: val_loss did not improve from 18962.34058
# Epoch 36/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 17515.4996 - mean_absolute_percentage_error: 18.7051 - mean_squared_error: 17515.4996 - mean_squared_error_1: 17515.4996 - val_loss: 20962.9545 - val_mean_absolute_percentage_error: 20.7644 - val_mean_squared_error: 20962.9545 - val_mean_squared_error_1: 20962.9545
#
# Epoch 00036: val_loss did not improve from 18962.34058
# Epoch 37/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 17581.4022 - mean_absolute_percentage_error: 18.6925 - mean_squared_error: 17581.4022 - mean_squared_error_1: 17581.4022 - val_loss: 21078.1163 - val_mean_absolute_percentage_error: 21.1169 - val_mean_squared_error: 21078.1163 - val_mean_squared_error_1: 21078.1163
#
# Epoch 00037: val_loss did not improve from 18962.34058
# Epoch 38/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 17231.0861 - mean_absolute_percentage_error: 18.5032 - mean_squared_error: 17231.0861 - mean_squared_error_1: 17231.0861 - val_loss: 21348.8895 - val_mean_absolute_percentage_error: 21.4893 - val_mean_squared_error: 21348.8895 - val_mean_squared_error_1: 21348.8895
#
# Epoch 00038: val_loss did not improve from 18962.34058
# Epoch 39/100
# 52500/52500 [==============================] - 2s 47us/step - loss: 17115.4493 - mean_absolute_percentage_error: 18.3851 - mean_squared_error: 17115.4493 - mean_squared_error_1: 17115.4493 - val_loss: 21482.8750 - val_mean_absolute_percentage_error: 21.1861 - val_mean_squared_error: 21482.8750 - val_mean_squared_error_1: 21482.8750
#
# Epoch 00039: val_loss did not improve from 18962.34058
# Epoch 40/100
# 52500/52500 [==============================] - 3s 48us/step - loss:
100
# 52500/52500 [==============================] - 3s 48us/step - loss: 15149.1225 - mean_absolute_percentage_error: 17.1089 - mean_squared_error: 15149.1225 - mean_squared_error_1: 15149.1225 - val_loss: 22889.0885 - val_mean_absolute_percentage_error: 21.4046 - val_mean_squared_error: 22889.0885 - val_mean_squared_error_1: 22889.0885
#
# Epoch 00048: val_loss did not improve from 18962.34058
# Epoch 49/100
# 52500/52500 [==============================] - 3s 49us/step - loss: 14965.0436 - mean_absolute_percentage_error: 16.9923 - mean_squared_error: 14965.0436 - mean_squared_error_1: 14965.0436 - val_loss: 23644.6291 - val_mean_absolute_percentage_error: 21.2316 - val_mean_squared_error: 23644.6291 - val_mean_squared_error_1: 23644.6291
#
# Epoch 00049: val_loss did not improve from 18962.34058
# Epoch 50/100
# 52500/52500 [==============================] - 2s 48us/step - loss: 14712.7201 - mean_absolute_percentage_error: 16.8351 - mean_squared_error: 14712.7201 - mean_squared_error_1: 14712.7201 - val_loss: 23454.1155 - val_mean_absolute_percentage_error: 21.3818 - val_mean_squared_error: 23454.1155 - val_mean_squared_error_1: 23454.1155
#
# Epoch 00050: val_loss did not improve from 18962.34058
# Epoch 51/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 14604.5395 - mean_absolute_percentage_error: 16.7436 - mean_squared_error: 14604.5395 - mean_squared_error_1: 14604.5395 - val_loss: 24419.7373 - val_mean_absolute_percentage_error: 21.6141 - val_mean_squared_error: 24419.7373 - val_mean_squared_error_1: 24419.7373
#
# Epoch 00051: val_loss did not improve from 18962.34058
# Epoch 52/100
# 52500/52500 [==============================] - 3s 49us/step - loss: 14385.9074 - mean_absolute_percentage_error: 16.5923 - mean_squared_error: 14385.9074 - mean_squared_error_1: 14385.9074 - val_loss: 24328.8264 - val_mean_absolute_percentage_error: 21.4041 - val_mean_squared_error: 24328.8264 - val_mean_squared_error_1: 24328.8264
#
# Epoch 00052: val_loss did not improve from 18962.34058
# Epoch 53/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 14221.2442 - mean_absolute_percentage_error: 16.4929 - mean_squared_error: 14221.2442 - mean_squared_error_1: 14221.2442 - val_loss: 24315.4093 - val_mean_absolute_percentage_error: 22.5801 - val_mean_squared_error: 24315.4093 - val_mean_squared_error_1: 24315.4093
#
# Epoch 00053: val_loss did not improve from 18962.34058
# Epoch 54/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 14102.1142 - mean_absolute_percentage_error: 16.3970 - mean_squared_error: 14102.1142 - mean_squared_error_1: 14102.1142 - val_loss: 24525.1326 - val_mean_absolute_percentage_error: 22.5907 - val_mean_squared_error: 24525.1326 - val_mean_squared_error_1: 24525.1326
#
# Epoch 00054: val_loss did not improve from 18962.34058
# Epoch 55/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 13808.0355 - mean_absolute_percentage_error: 16.2061 - mean_squared_error: 13808.0355 - mean_squared_error_1: 13808.0355 - val_loss: 24841.8901 - val_mean_absolute_percentage_error: 21.6678 - val_mean_squared_error: 24841.8901 - val_mean_squared_error_1: 24841.8901
#
# Epoch 00055: val_loss did not improve from 18962.34058
# Epoch 56/100
# 52500/52500 [==============================] - 3s 48us/step - loss:
100
# 52500/52500 [==============================] - 3s 48us/step - loss: 12433.7672 - mean_absolute_percentage_error: 15.2744 - mean_squared_error: 12433.7672 - mean_squared_error_1: 12433.7672 - val_loss: 26610.9898 - val_mean_absolute_percentage_error: 22.4055 - val_mean_squared_error: 26610.9898 - val_mean_squared_error_1: 26610.9898
#
# Epoch 00065: val_loss did not improve from 18962.34058
# Epoch 66/100
# 52500/52500 [==============================] - 2s 47us/step - loss: 12147.8142 - mean_absolute_percentage_error: 15.0642 - mean_squared_error: 12147.8142 - mean_squared_error_1: 12147.8142 - val_loss: 26459.6813 - val_mean_absolute_percentage_error: 22.5748 - val_mean_squared_error: 26459.6813 - val_mean_squared_error_1: 26459.6813
#
# Epoch 00066: val_loss did not improve from 18962.34058
# Epoch 67/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 12172.7423 - mean_absolute_percentage_error: 15.0777 - mean_squared_error: 12172.7423 - mean_squared_error_1: 12172.7423 - val_loss: 26199.6921 - val_mean_absolute_percentage_error: 22.5973 - val_mean_squared_error: 26199.6921 - val_mean_squared_error_1: 26199.6921
#
# Epoch 00067: val_loss did not improve from 18962.34058
# Epoch 68/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 11932.5188 - mean_absolute_percentage_error: 14.9432 - mean_squared_error: 11932.5188 - mean_squared_error_1: 11932.5188 - val_loss: 26768.6217 - val_mean_absolute_percentage_error: 22.5420 - val_mean_squared_error: 26768.6217 - val_mean_squared_error_1: 26768.6217
#
# Epoch 00068: val_loss did not improve from 18962.34058
# Epoch 69/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 11874.0660 - mean_absolute_percentage_error: 14.8792 - mean_squared_error: 11874.0660 - mean_squared_error_1: 11874.0660 - val_loss: 26001.5794 - val_mean_absolute_percentage_error: 22.6595 - val_mean_squared_error: 26001.5794 - val_mean_squared_error_1: 26001.5794
#
# Epoch 00069: val_loss did not improve from 18962.34058
# Epoch 70/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 11734.7401 - mean_absolute_percentage_error: 14.7583 - mean_squared_error: 11734.7401 - mean_squared_error_1: 11734.7401 - val_loss: 26725.7020 - val_mean_absolute_percentage_error: 23.0894 - val_mean_squared_error: 26725.7020 - val_mean_squared_error_1: 26725.7020
#
# Epoch 00070: val_loss did not improve from 18962.34058
# Epoch 71/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 11589.1395 - mean_absolute_percentage_error: 14.6847 - mean_squared_error: 11589.1395 - mean_squared_error_1: 11589.1395 - val_loss: 27487.4716 - val_mean_absolute_percentage_error: 22.8158 - val_mean_squared_error: 27487.4716 - val_mean_squared_error_1: 27487.4716
#
# Epoch 00071: val_loss did not improve from 18962.34058
# Epoch 72/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 11505.5273 - mean_absolute_percentage_error: 14.5818 - mean_squared_error: 11505.5273 - mean_squared_error_1: 11505.5273 - val_loss: 27052.7127 - val_mean_absolute_percentage_error: 22.4904 - val_mean_squared_error: 27052.7127 - val_mean_squared_error_1: 27052.7127
#
# Epoch 00072: val_loss did not improve from 18962.34058
# Epoch 73/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 11404.6171 - mean_absolute_percentage_error: 14.5602 - mean_squared_error: 11404.6171 - mean_squared_error_1: 11404.6171 - val_loss: 26897.9176 - val_mean_absolute_percentage_error: 22.7779 - val_mean_squared_error: 26897.9176 - val_mean_squared_error_1: 26897.9176
#
# Epoch 00073: val_loss did not improve from 18962.34058
# Epoch 74/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 11279.3785 - mean_absolute_percentage_error: 14.4215 - mean_squared_error: 11279.3785 - mean_squared_error_1: 11279.3785 - val_loss: 29135.7455 - val_mean_absolute_percentage_error: 22.7230 - val_mean_squared_error: 29135.7455 - val_mean_squared_error_1: 29135.7455
#
# Epoch 00074: val_loss did not improve from 18962.34058
# Epoch 75/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 11234.2080 - mean_absolute_percentage_error: 14.4162 - mean_squared_error: 11234.2080 - mean_squared_error_1: 11234.2080 - val_loss: 27789.8445 - val_mean_absolute_percentage_error: 23.3285 - val_mean_squared_error: 27789.8445 - val_mean_squared_error_1: 27789.8445
#
# Epoch 00075: val_loss did not improve from 18962.34058
# Epoch 76/100
# 52500/52500 [==============================] - 2s 47us/step - loss: 11025.2048 - mean_absolute_percentage_error: 14.2870 - mean_squared_error: 11025.2048 - mean_squared_error_1: 11025.2048 - val_loss: 27094.0875 - val_mean_absolute_percentage_error: 23.0457 - val_mean_squared_error: 27094.0875 - val_mean_squared_error_1: 27094.0875
#
# Epoch 00076: val_loss did not improve from 18962.34058
# Epoch 77/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 11001.2132 - mean_absolute_percentage_error: 14.2730 - mean_squared_error: 11001.2132 - mean_squared_error_1: 11001.2132 - val_loss: 27339.9939 - val_mean_absolute_percentage_error: 22.9456 - val_mean_squared_error: 27339.9939 - val_mean_squared_error_1: 27339.9939
#
# Epoch 00077: val_loss did not improve from 18962.34058
# Epoch 78/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 10783.3873 - mean_absolute_percentage_error: 14.0520 - mean_squared_error: 10783.3873 - mean_squared_error_1: 10783.3873 - val_loss: 27995.0788 - val_mean_absolute_percentage_error: 23.8565 - val_mean_squared_error: 27995.0788 - val_mean_squared_error_1: 27995.0788
#
# Epoch 00078: val_loss did not improve from 18962.34058
# Epoch 79/100
# 52500/52500 [==============================] - 3s 49us/step - loss: 10768.9002 - mean_absolute_percentage_error: 14.0579 - mean_squared_error: 10768.9002 - mean_squared_error_1: 10768.9002 - val_loss: 27498.0632 - val_mean_absolute_percentage_error: 23.1434 - val_mean_squared_error: 27498.0632 - val_mean_squared_error_1: 27498.0632
#
# Epoch 00079: val_loss did not improve from 18962.34058
# Epoch 80/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 10570.6676 - mean_absolute_percentage_error: 13.9604 - mean_squared_error: 10570.6676 - mean_squared_error_1: 10570.6676 - val_loss: 27764.7368 - val_mean_absolute_percentage_error: 23.3407 - val_mean_squared_error: 27764.7368 - val_mean_squared_error_1: 27764.7368
#
# Epoch 00080: val_loss did not improve from 18962.34058
# Epoch 81/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 10541.7518 - mean_absolute_percentage_error: 13.9283 - mean_squared_error: 10541.7518 - mean_squared_error_1: 10541.7518 - val_loss: 27861.4227 - val_mean_absolute_percentage_error: 23.0833 - val_mean_squared_error: 27861.4227 - val_mean_squared_error_1: 27861.4227
#
# Epoch 00081: val_loss did not improve from 18962.34058
# Epoch 82/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 10410.1095 - mean_absolute_percentage_error: 13.7882 - mean_squared_error: 10410.1095 - mean_squared_error_1: 10410.1095 - val_loss: 27988.5053 - val_mean_absolute_percentage_error: 23.6547 - val_mean_squared_error: 27988.5053 - val_mean_squared_error_1: 27988.5053
#
# Epoch 00082: val_loss did not improve from 18962.34058
# Epoch 83/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 10229.5710 - mean_absolute_percentage_error: 13.7107 - mean_squared_error: 10229.5710 - mean_squared_error_1: 10229.5710 - val_loss: 28199.4707 - val_mean_absolute_percentage_error: 23.4512 - val_mean_squared_error: 28199.4707 - val_mean_squared_error_1: 28199.4707
#
# Epoch 00083: val_loss did not improve from 18962.34058
# Epoch 84/100
# 52500/52500 [==============================] - 3s 49us/step - loss: 10253.5326 - mean_absolute_percentage_error: 13.7084 - mean_squared_error: 10253.5326 - mean_squared_error_1: 10253.5326 - val_loss: 29280.2014 - val_mean_absolute_percentage_error: 23.1645 - val_mean_squared_error: 29280.2014 - val_mean_squared_error_1: 29280.2014
#
# Epoch 00084: val_loss did not improve from 18962.34058
# Epoch 85/100
# 52500/52500 [==============================] - 3s 49us/step - loss: 10044.6337 - mean_absolute_percentage_error: 13.5529 - mean_squared_error: 10044.6337 - mean_squared_error_1: 10044.6337 - val_loss: 28482.5149 - val_mean_absolute_percentage_error: 23.0800 - val_mean_squared_error: 28482.5149 - val_mean_squared_error_1: 28482.5149
#
# Epoch 00085: val_loss did not improve from 18962.34058
# Epoch 86/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 10029.2234 - mean_absolute_percentage_error: 13.5343 - mean_squared_error: 10029.2234 - mean_squared_error_1: 10029.2234 - val_loss: 27448.4503 - val_mean_absolute_percentage_error: 23.1180 - val_mean_squared_error: 27448.4503 - val_mean_squared_error_1: 27448.4503
#
# Epoch 00086: val_loss did not improve from 18962.34058
# Epoch 87/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 9836.1254 - mean_absolute_percentage_error: 13.4015 - mean_squared_error: 9836.1254 - mean_squared_error_1: 9836.1254 - val_loss: 28497.8687 - val_mean_absolute_percentage_error: 23.4212 - val_mean_squared_error: 28497.8687 - val_mean_squared_error_1: 28497.8687
#
# Epoch 00087: val_loss did not improve from 18962.34058
# Epoch 88/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 9890.7775 - mean_absolute_percentage_error: 13.4195 - mean_squared_error: 9890.7775 - mean_squared_error_1: 9890.7775 - val_loss: 28333.8382 - val_mean_absolute_percentage_error: 23.4427 - val_mean_squared_error: 28333.8382 - val_mean_squared_error_1: 28333.8382
#
# Epoch 00088: val_loss did not improve from 18962.34058
# Epoch 89/100
# 52500/52500 [==============================] - 2s 47us/step - loss: 9784.4278 - mean_absolute_percentage_error: 13.3566 - mean_squared_error: 9784.4278 - mean_squared_error_1: 9784.4278 - val_loss: 31401.8359 - val_mean_absolute_percentage_error: 23.5649 - val_mean_squared_error: 31401.8359 - val_mean_squared_error_1: 31401.8359
#
# Epoch 00089: val_loss did not improve from 18962.34058
# Epoch 90/100
# 52500/52500 [==============================] - 3s 48us/step - loss:
# 52500/52500 [==============================] - 2s 48us/step - loss: 9014.3836 - mean_absolute_percentage_error: 12.8150 - mean_squared_error: 9014.3836 - mean_squared_error_1: 9014.3836 - val_loss: 29011.2086 - val_mean_absolute_percentage_error: 23.6944 - val_mean_squared_error: 29011.2086 - val_mean_squared_error_1: 29011.2086
#
# Epoch 00099: val_loss did not improve from 18962.34058
# Epoch 100/100
# 52500/52500 [==============================] - 3s 48us/step - loss: 8886.0887 - mean_absolute_percentage_error: 12.7043 - mean_squared_error: 8886.0887 - mean_squared_error_1: 8886.0887 - val_loss: 31180.6443 - val_mean_absolute_percentage_error: 23.6154 - val_mean_squared_error: 31180.6443 - val_mean_squared_error_1: 31180.6443
#
# Epoch 00100: val_loss did not improve from 18962.34058

# %% [markdown]
# ### Print Model - Fully Connected

# %%
import matplotlib.pyplot as plt_fc

print(hist_fc.history.keys())

plt_fc.plot(hist_fc.history['loss'])
plt_fc.plot(hist_fc.history['val_loss'])
plt_fc.title('Model FC - Loss')
plt_fc.ylabel('Loss')
plt_fc.xlabel('Epoch')
plt_fc.legend(['Train', 'Validation'])
plt_fc.show()

plt_fc.plot(hist_fc.history['mean_squared_error'])
plt_fc.plot(hist_fc.history['val_mean_squared_error'])
plt_fc.title('Model FC - MSE')
plt_fc.ylabel('MSE')
plt_fc.xlabel('Epoch')
plt_fc.legend(['Train', 'Validation'])
plt_fc.show()

plt_fc.plot(hist_fc.history['mean_absolute_percentage_error'])
plt_fc.plot(hist_fc.history['val_mean_absolute_percentage_error'])
plt_fc.title('Model FC - Mean Absolute Precentage Error')
plt_fc.ylabel('MAPE')
plt_fc.xlabel('Epoch')
plt_fc.legend(['Train', 'Validation'])
plt_fc.show()
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_percentage_error', 'val_mean_squared_error', 'val_mean_squared_error_1', 'loss', 'mean_absolute_percentage_error', 'mean_squared_error', 'mean_squared_error_1'])

# %% [markdown]
# ### Evaluate Model - Fully Connected

# %%
batch_size = 128
score_fc = model_fc.evaluate(dataFC_test_data, dataFC_test_target1, batch_size=batch_size)
print(model_fc.metrics_names)
print(score_fc)
print('Model FC Accuracy:', 100-round(score_fc[1], 2), '%.')

# %% [markdown]
# ## Model - Convolution 1D

# %% [markdown]
# ### Data Preprocess - Convolution 1D

# %%
import numpy as np_cnn1d

path = '/GoogleDrive/My Drive/project_0330342797_038628343/data/OurData/'
pathOutput = '/GoogleDrive/My Drive/project_0330342797_038628343/outputWeights/'
file='data_NN_1500_records_from038_to088_for_each_hundretch_of_each_bacteria_75000_Records.npy'
file1 ='data_NN_betaFamily_263379.npy'
file2 = 'data_NN_all_up_to_13_for_each_hundretch_of_each_bacteria_270274_Records.npy'
dataCNN1D = np_cnn1d.load(path+file)
print(dataCNN1D.shape)

# %%
# split data to train, valid, test --> with shuffling

from sklearn.model_selection import train_test_split

dataCNN1D_train, dataCNN1D_validate = train_test_split(dataCNN1D,train_size=0.7,test_size=0.3, random_state=42)
dataCNN1D_validate, dataCNN1D_test = train_test_split(dataCNN1D_validate,train_size=0.50,test_size=0.50, random_state=42)

# Train
dataCNN1D_train_data = dataCNN1D_train[:,0:200]
dataCNN1D_train_data = dataCNN1D_train_data.reshape(dataCNN1D_train_data.shape[0],200,1)
dataCNN1D_train_target = dataCNN1D_train[:,200]

dataCNN1D_train_target1 = dataCNN1D_train[:,200]*1000
dataCNN1D_train_target1 = dataCNN1D_train_target1.astype(np_cnn1d.int64)

print('train data shapes')
print(dataCNN1D_train_data.shape)
print(dataCNN1D_train_target1.shape)

# Validation
dataCNN1D_validate_data = dataCNN1D_validate [:,0:200]
dataCNN1D_validate_data = dataCNN1D_validate_data.reshape(dataCNN1D_validate_data.shape[0],200,1)
dataCNN1D_validate_target = dataCNN1D_validate[:,200]

dataCNN1D_validate_target1 = dataCNN1D_validate[:,200]*1000
dataCNN1D_validate_target1 = dataCNN1D_validate_target1.astype(np_cnn1d.int64)

print('validation data shapes')
print(dataCNN1D_validate_data.shape)
print(dataCNN1D_validate_target1.shape)

# Test
dataCNN1D_test_data = dataCNN1D_test[:,0:200]
dataCNN1D_test_data = dataCNN1D_test_data.reshape(dataCNN1D_test_data.shape[0],200,1)
dataCNN1D_test_target = dataCNN1D_test[:,200]

dataCNN1D_test_target1 = dataCNN1D_test[:,200]*1000
dataCNN1D_test_target1 = dataCNN1D_test_target1.astype(np_cnn1d.int64)

print('test data shapes')
print(dataCNN1D_test_data.shape)
print(dataCNN1D_test_target1.shape)

# %% [markdown]
# ### Load Existing Model - Convolution 1D

# %%
# this block should be run only if we want to load a saved models and use it (instead or fitting the model again):
from keras.models import load_model

# Load best results
file_cnn1d_best1 ='Weights-048--109.99619.hdf5'
file_cnn1d_best = 'Weights-042--110.18304.hdf5'
model_cnn1d = load_model(pathOutput+'convolution1d/'+file_cnn1d_best)

# now we can use the model our model for example:

batch_size_cnn1d = 100

score_cnn1d = model_cnn1d.evaluate(dataCNN1D_test_data, dataCNN1D_test_target1, batch_size=batch_size_cnn1d)
print('Best Results')
print(model_cnn1d.metrics_names)
print(score_cnn1d)
print('Model CNN1D Accuracy:', 100-round(score_cnn1d[1], 2), '%.')

# %% [markdown]
# ### Build Model - Convolution 1D

# %%
from keras.models import Sequential
from keras import models, layers
import keras

# Instantiate an empty model
model_cnn1d = Sequential()
model_cnn1d.reset_states()

# Layer1 - Convolutional Layer 1 dimension
#keras.layers.Conv1D(filters, kernel_size, strides=1, padding='valid', data_format='channels_last', dilation_rate=1, 
#activation=None, use_bias=True, kernel_initializer='glorot_uniform', bias_initializer='zeros', kernel_regularizer=None, 
#bias_regularizer=None, activity_regularizer=None, kernel_constraint=None, bias_constraint=None)

model_cnn1d.add(layers.Conv1D(filters=50, kernel_size=4, strides=4, activation='relu', input_shape=(200,1), padding='valid'))
#model_cnn1d.add(layers.Conv1D(filters=50, kernel_size=4, strides=1, activation='relu', input_shape=(200,1), padding='same'))

# Layer2 - Pooling Layer
model_cnn1d.add(layers.MaxPooling1D(pool_size=3, strides=3, padding='valid'))
#model_cnn1d.add(layers.MaxPooling1D(pool_size=8, strides=4, padding='same'))

# Layer3 - Convolutional Layer
model_cnn1d.add(layers.Conv1D(50, kernel_size=3, strides=1, activation='relu', padding='valid'))
#model_cnn1d.add(layers.Conv1D(50, kernel_size=2, strides=1, activation='relu', padding='valid'))

# Layer4 - Pooling Layer
model_cnn1d.add(layers.AveragePooling1D(pool_size=3, strides=3, padding='valid'))

# Layer5 - Fully Connected Convolutional Layer
model_cnn1d.add(layers.Conv1D(50, kernel_size=3, strides=1, activation='relu', padding='valid'))

# Flatten the CNN output so that we can connect it with fully connected layers
model_cnn1d.add(layers.Flatten())

# Layer6 -  Fully Connected Layer
model_cnn1d.add(layers.Dense(150, activation='relu'))

#model_cnn1d.add(layers.Dropout(0))

# Layer7 - Output Layer with linear activation and 1 output - for regression
model_cnn1d.add(layers.Dense(1, activation='linear'))

model_cnn1d.summary()

# %% [markdown]
# ### Train Model - Convolution 1D

# %%
from keras.callbacks import ModelCheckpoint

checkpoint_cnn1d_name = pathOutput+'convolution1d/Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint_cnn1d = ModelCheckpoint(checkpoint_cnn1d_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_cnn1d_list = [checkpoint_cnn1d]


# More Params
batch_size_cnn1d = 250
epoch_cnn1d = 100

# Compile the model
model_cnn1d.reset_states()
model_cnn1d.compile(loss='mse', optimizer='adam', metrics=['mape','mae', 'mse'])
#model_cnn1d.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mape','mse'])

# Train
hist_cnn1d = model_cnn1d.fit(dataCNN1D_train_data, dataCNN1D_train_target1, validation_data=(dataCNN1D_validate_data,dataCNN1D_validate_target1), batch_size=batch_size_cnn1d, epochs=epoch_cnn1d, callbacks=callbacks_cnn1d_list)

# %% [markdown]
# ### Evaluate Model - Convolution 1D

# %%
# Evaluate
batch_size_cnn1d = 100
score_cnn1d = model_cnn1d.evaluate(dataCNN1D_test_data, dataCNN1D_test_target1, batch_size=batch_size_cnn1d)
print(model_cnn1d.metrics_names)
print (score_cnn1d)
print('Model CNN1D Accuracy:', 100-round(score_cnn1d[1], 2), '%.')

# %% [markdown]
# ### Plot Model

# %%
import matplotlib.pyplot as plt_cnn1d

print(hist_cnn1d.history.keys())

plt_cnn1d.ylim(top=21000)
plt_cnn1d.ylim(bottom=18500)
plt_cnn1d.xlim(right=250)
plt_cnn1d.xlim(left=0)
plt_cnn1d.plot(hist_cnn1d.history['loss'])
plt_cnn1d.plot(hist_cnn1d.history['val_loss'])
plt_cnn1d.title('Model CNN1D - Loss')
plt_cnn1d.ylabel('Loss')
plt_cnn1d.xlabel('Epoch')
plt_cnn1d.legend(['Train', 'Validation'])
plt_cnn1d.show()

plt_cnn1d.plot(hist_cnn1d.history['mean_squared_error'])
plt_cnn1d.plot(hist_cnn1d.history['val_mean_squared_error'])
plt_cnn1d.title('Model CNN1D - MSE')
plt_cnn1d.ylabel('MSE')
plt_cnn1d.xlabel('Epoch')
plt_cnn1d.legend(['Train', 'Validation'])
plt_cnn1d.show()


plt_cnn1d.plot(hist_cnn1d.history['mean_absolute_percentage_error'])
plt_cnn1d.plot(hist_cnn1d.history['val_mean_absolute_percentage_error'])
plt_cnn1d.title('Model CNN1D - MAPE')
plt_cnn1d.ylabel('MAPE')
plt_cnn1d.xlabel('Epoch')
plt_cnn1d.legend(['Train', 'Validation'])
plt_cnn1d.show()

# %% [markdown]
# ## Model - Convolution 2D

# %% [markdown]
# ### Data Preprocess - Convolution 2D

# %%
import numpy as np_cnn2d

path = '/GoogleDrive/My Drive/project_0330342797_038628343/data/OurData/'
pathOutput = '/GoogleDrive/My Drive/project_0330342797_038628343/outputWeights/'
file='data_NN_1500_records_from038_to088_for_each_hundretch_of_each_bacteria_75000_Records.npy'
file1 ='data_NN_betaFamily_263379.npy'
file2 = 'data_NN_all_up_to_13_for_each_hundretch_of_each_bacteria_270274_Records.npy'


dataCNN2D = np_cnn2d.load(path+file)
print(dataCNN2D.shape)

# %%
# split data to train, valid, test --> with shuffling

from sklearn.model_selection import train_test_split

dataCNN2D_train, dataCNN2D_validate = train_test_split(dataCNN2D,train_size=0.7,test_size=0.3, random_state=42)
dataCNN2D_validate, dataCNN2D_test = train_test_split(dataCNN2D_validate,train_size=0.50,test_size=0.50, random_state=42)

# train data
dataCNN2D_train_data = dataCNN2D_train[:,0:200]
dataCNN2D_train_data = dataCNN2D_train_data.reshape(dataCNN2D_train_data.shape[0],4,50,1)
dataCNN2D_train_target = dataCNN2D_train[:,200]

dataCNN2D_train_target1 = dataCNN2D_train[:,200]*1000
dataCNN2D_train_target1 = dataCNN2D_train_target1.astype(np_cnn2d.int64)

print('train data shapes')
print(dataCNN2D_train_data.shape)
print(dataCNN2D_train_target1.shape)

# validation data
dataCNN2D_validate_data = dataCNN2D_validate [:,0:200]
dataCNN2D_validate_data = dataCNN2D_validate_data.reshape(dataCNN2D_validate_data.shape[0],4,50,1)
dataCNN2D_validate_target = dataCNN2D_validate[:,200]

dataCNN2D_validate_target1 = dataCNN2D_validate[:,200]*1000
dataCNN2D_validate_target1 = dataCNN2D_validate_target1.astype(np_cnn2d.int64)

print('validation data shapes')
print(dataCNN2D_validate_data.shape)
print(dataCNN2D_validate_target1.shape)


# test data
dataCNN2D_test_data = dataCNN2D_test[:,0:200]
dataCNN2D_test_data = dataCNN2D_test_data.reshape(dataCNN2D_test_data.shape[0],4,50,1)
dataCNN2D_test_target = dataCNN2D_test[:,200]

dataCNN2D_test_target1 = dataCNN2D_test[:,200]*1000
dataCNN2D_test_target1 = dataCNN2D_test_target1.astype(np_cnn2d.int64)

print('test data shapes')
print(dataCNN2D_test_data.shape)
print(dataCNN2D_test_target1.shape)

# %% [markdown]
# ### Load Existing Model - Convolution 2D

# %%
# this block should be run only if we want to load a saved models and use it (instead or fitting the model again):
from keras.models import load_model

# Load best results
file_cnn2d_best1 ='Weights-006--117.57759.hdf5'
file_cnn2d_best = 'Weights-016--108.77296.hdf5'
model_cnn2d = load_model(pathOutput+'convolution2d/'+file_cnn2d_best)

# now we can use the model our model for example:

batch_size_cnn2d = 100

score_cnn2d = model_cnn2d.evaluate(dataCNN2D_test_data, dataCNN2D_test_target1, batch_size=batch_size_cnn2d)
print('Best Results')
print(model_cnn2d.metrics_names)
print(score_cnn2d)
print('Model CNN2D Accuracy:', 100-round(score_cnn2d[1], 2), '%.')

# %% [markdown]
# ### Build Model - Convolution 2D

# %%
from keras.models import Sequential
from keras import models, layers
import keras

# Instantiate an empty model
model_cnn2d = Sequential()
model_cnn2d.reset_states()


# Instantiate an empty model
model_cnn2d = Sequential()

# Layer1 - Convolutional Layer
model_cnn2d.add(layers.Conv2D(50, kernel_size=(4, 1), strides=(1, 1), activation='relu', input_shape=(4, 50, 1), padding='same'))
model_cnn2d.add(layers.BatchNormalization())


# Layer2 - Pooling Layer
model_cnn2d.add(layers.MaxPooling2D(pool_size=(4,3), strides=(1, 1), padding='same'))

# Layer3 - Convolutional Layer
model_cnn2d.add(layers.Conv2D(50, kernel_size=(4, 3), strides=(1, 1), activation='relu', padding='same'))
model_cnn2d.add(layers.BatchNormalization())

# Layer4 - Pooling Layer
model_cnn2d.add(layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

# Layer5 - Fully Connected Convolutional Layer
model_cnn2d.add(layers.Conv2D(120, kernel_size=(1, 3), strides=(1, 1), activation='relu', padding='same'))
model_cnn2d.add(layers.BatchNormalization())

# Flatten the CNN output so that we can connect it with fully connected layers
model_cnn2d.add(layers.Flatten())

# Layer6 -  Fully Connected Layer
model_cnn2d.add(layers.Dense(150, activation='relu'))

model_cnn2d.add(layers.Dropout(0.5))

# Layer7 - Output Layer with linear activation and 1 output - for regression net
model_cnn2d.add(layers.Dense(1, activation='relu'))

model_cnn2d.summary()

# %% [markdown]
# ### Visualize Model - Convolution 2D

# %%
from keras.utils import plot_model

plot_model(model_cnn2d, to_file=pathOutput+'convolution2d/'+'model_cnn2d.png', show_shapes = True, show_layer_names = True)
#check why dpi=200 is not supported

# %% [markdown]
# ### Train Model - Convolution 2D

# %%
from keras.callbacks import ModelCheckpoint

checkpoint_cnn2d_name = pathOutput+'convolution2d/Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint_cnn2d = ModelCheckpoint(checkpoint_cnn2d_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_cnn2d_list = [checkpoint_cnn2d]


# More Params
batch_size_cnn2d = 250
epoch_cnn2d = 50
#optimizer_cnn2d = optimizers.Adam(lr=0.001, decay=0.000, amsgrad=False)
#optimizer_cnn2d = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

# Compile the model
model_cnn2d.reset_states()
model_cnn2d.compile(loss='mse', optimizer= 'adam', metrics=['mape','mse','mae'])

# Train
hist_cnn2d = model_cnn2d.fit(dataCNN2D_train_data, dataCNN2D_train_target1, validation_data=(dataCNN2D_validate_data,dataCNN2D_validate_target1), batch_size=batch_size_cnn2d, epochs=epoch_cnn2d, callbacks=callbacks_cnn2d_list)

# %% [markdown]
# ### Evaluate - Model - Convolution 2D

# %%
# Evaluate

batch_size_cnn2d = 100

score_cnn2d = model_cnn2d.evaluate(dataCNN2D_test_data, dataCNN2D_test_target1, batch_size=batch_size_cnn2d)

print(model_cnn2d.metrics_names)
print(score_cnn2d)
print('Model CNN2D Accuracy:', 100-round(score_cnn2d[1], 2), '%.')

# %% [markdown]
# ### Plot Model

# %%
import matplotlib.pyplot as plt_cnn2d

print(hist_cnn2d.history.keys())

plt_cnn2d.ylim(top=30000)
plt_cnn2d.ylim(bottom=16000)
plt_cnn2d.xlim(right=50)
plt_cnn2d.xlim(left=0)
plt_cnn2d.plot(hist_cnn2d.history['loss'])
plt_cnn2d.plot(hist_cnn2d.history['val_loss'])
plt_cnn2d.title('Model CNN2D - Loss')
plt_cnn2d.ylabel('Loss')
plt_cnn2d.xlabel('Epoch')
plt_cnn2d.legend(['Train', 'Validation'])
plt_cnn2d.show()

plt_cnn2d.plot(hist_cnn2d.history['mean_squared_error'])
plt_cnn2d.plot(hist_cnn2d.history['val_mean_squared_error'])
plt_cnn2d.title('Model CNN2D - MSE')
plt_cnn2d.ylabel('MSE')
plt_cnn2d.xlabel('Epoch')
plt_cnn2d.legend(['Train', 'Validation'])
plt_cnn2d.show()


plt_cnn2d.plot(hist_cnn2d.history['mean_absolute_percentage_error'])
plt_cnn2d.plot(hist_cnn2d.history['val_mean_absolute_percentage_error'])
plt_cnn2d.title('Model CNN2D - MAPE')
plt_cnn2d.ylabel('MAPE')
plt_cnn2d.xlabel('Epoch')
plt_cnn2d.legend(['Train', 'Validation'])
plt_cnn2d.show()

# %% [markdown]
# ### > Save Model

# %%
# if we want to save the model for later use we whould run this code block:
model_1.save("/GoogleDrive/My Drive/ex1_0330342797_038628343/model_1.h5")

# %% [markdown]
# ## Model - Random Forest Regression

# %% [markdown]
# ### Data Preprocess - Random Forest

# %%
import numpy as np_rf

path = '/GoogleDrive/My Drive/project_0330342797_038628343/data/OurData/'
pathOutput = '/GoogleDrive/My Drive/project_0330342797_038628343/randomForest/'
file='data_random_forest_1500_records_from037_to087_for_each_hundretch_of_each_bacteria_75000_Records.npy'
file1 ='data_random_forest_betaFamily_263379.npy'
dataRF = np_rf.load(path+file)

print(dataRF.shape)
# Out:
# (75000, 51)

# %%
# split data to train, test --> with shuffling

from sklearn.model_selection import train_test_split

dataRF_train, dataRF_test = train_test_split(dataRF,train_size=0.7,test_size=0.3)

# train data + target
dataRF_train_data = dataRF_train[:,0:50]
dataRF_train_target = dataRF_train[:,50]
print('dataRF_train_data.shape',dataRF_train_data.shape[1])
print('dataRF_train_data',dataRF_train_data[1])

dataRF_train_target1 = dataRF_train[:,50]*1000
dataRF_train_target1 = dataRF_train_target1.astype(np_rf.int64)
print('dataRF_train_target1',dataRF_train_target1[1:10])

# test data + target
dataRF_test_data = dataRF_test[:,0:50]
dataRF_test_target = dataRF_test[:,50]
print('dataRF_test_data.shape',dataRF_test_data.shape[1])
print('dataRF_test_data',dataRF_test_data[1])

dataRF_test_target1 = dataRF_test[:,50]*1000
dataRF_test_target1 = dataRF_test_target1.astype(np_rf.int64)
print('dataRF_test_target1',dataRF_test_target1[1:10])

# our feature list in this case is the position of the nucleotide 1-50
featuresRF=np_rf.arange(1,51)
# Out:
# dataRF_train_data.shape 50
# dataRF_train_data [2. 1. 2. 3. 1. 2. 4. 4. 1. 1. 4. 4. 3. 2. 2. 2. 3. 4. 2. 4. 2. 1. 4. 2.
#  3. 1. 3. 2. 3. 3. 3. 2. 2. 3. 1. 4. 4. 4. 3. 3. 1. 1. 4. 4. 4. 3. 1. 1.
#  3. 4.]
# dataRF_train_target1 [429 765 738 456 521 573 620 583 726]
# dataRF_test_data.shape 50
# dataRF_test_data [4. 2. 1. 1. 4. 4. 4. 2. 3. 3. 1. 1. 3. 1. 1. 4. 3. 4. 1. 4. 4. 2. 2. 3.
#  3. 2. 1. 4. 2. 4. 3. 1. 3. 1. 4. 1. 3. 1. 1. 1. 2. 1. 3. 3. 1. 1. 4. 4.
#  2. 2.]
# dataRF_test_target1 [506 770 778 554 555 398 712 855 412]

# %% [markdown]
# ### Model Train - Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

#setting random seed
np_rf.random.seed(0)

rfrg = RandomForestRegressor(n_estimators = 500, max_depth = 5, criterion = 'mse', random_state = 42)
rfrg.fit(dataRF_train_data, dataRF_train_target1)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=5,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=None,
#            oob_score=False, random_state=42, verbose=0, warm_start=False)

# %% [markdown]
# ### Determine Performance Metrics

# %%
# Use the forest's predict method on the test data
predictions_rf = rfrg.predict(dataRF_test_data)

# Calculate the absolute errors
errors_rf = abs(predictions_rf - dataRF_test_target1)

errors_sqrd_rf = errors_rf*errors_rf

# Print out the mean squared error (mse)
print('Baseline Mean Squared Error:', round(np_rf.mean(errors_sqrd_rf), 2))

# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np_rf.mean(errors_rf), 2))

# Calculate mean absolute percentage error (MAPE)
mape_rf = 100 * (errors_rf / dataRF_test_target1)

# Calculate and display accuracy
accuracy_rf = 100 - np_rf.mean(mape_rf)

print('Accuracy:', round(accuracy_rf, 2), '%.')
# Out:
# Baseline Mean Squared Error: 20098.02
# Mean Absolute Error: 122.75
# Accuracy: 78.58 %.

# %% [markdown]
# ### Visualitazion - Tree

# %%
# Import tools needed for visualization
from sklearn.tree import export_graphviz
import pydot

# Pull out one tree from the forest
tree = rfrg.estimators_[0]

# Export the image to a dot file
export_graphviz(tree, out_file = 'tree.dot', feature_names=featuresRF, rounded = True, precision = 1)

# Use dot file to create a graph
(graph, ) = pydot.graph_from_dot_file('tree.dot')

# Write graph to a png file
graph.write_png(pathOutput+'tree.png')

# %% [markdown]
# ### Visualization - Importances

# %%
importances = list(rfrg.feature_importances_)
print(importances)

import matplotlib.pyplot as plt
# %matplotlib inline

# Set the style
plt.style.use('fivethirtyeight')

# list of x locations for plotting
x_values = list(range(len(importances)))

# Make a bar chart
plt.bar(x_values, importances, orientation = 'vertical')

# Tick labels for x axis
plt.xticks(x_values, featuresRF, rotation='vertical')

# Axis labels and title
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');

# %% [markdown]
# # Lenet 5 - Dropout layer

# %% [markdown]
# ### > Load Exsisting Model

# %%
# this block should be run only if we want to load a saved models and use it (instead or fitting the model again):
from keras.models import Sequential
from keras import models, layers
import keras
from keras.models import load_model

model_2 = load_model('/GoogleDrive/My Drive/ex1_0330342797_038628343/model_2.h5')

# now we can use the model our model for example:
batch_size = 128
score_2 = model_2.evaluate(x_test, y_test, batch_size=batch_size)


print (score_2)

# %% [markdown]
# ### >Train Model

# %%
from keras.models import Sequential
from keras import models, layers
from keras.layers import Dropout
import keras

# More Params
batch_size = 128
epoch = 10

# Instantiate an empty model
model_2 = Sequential()

# Layer1 - Convolutional Layer
model_2.add(layers.Conv2D(6, kernel_size=(5, 5), strides=(1, 1), activation='relu', input_shape=(28,28,1), padding='same'))

# Layer2 - Pooling Layer
model_2.add(layers.AveragePooling2D(pool_size=(2, 2), strides=(1, 1), padding='valid'))

# Layer3 - Convolutional Layer
model_2.add(layers.Conv2D(16, kernel_size=(5, 5), strides=(1, 1), activation='relu', padding='valid'))

# Layer4 - Pooling Layer
model_2.add(layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

# Layer5 - Fully Connected Convolutional Layer
model_2.add(layers.Conv2D(120, kernel_size=(5, 5), strides=(1, 1), activation='relu', padding='valid'))

# Flatten the CNN output so that we can connect it with fully connected layers
model_2.add(layers.Flatten())

# Layer6 -  Fully Connected Layer
model_2.add(layers.Dense(84, activation='relu'))

#################################################
########   addding the dropout:  ################

model_2.add(Dropout(0.1))

# Remark: We read that keras disable the dropout for validation data so no need to disable this layer property
#################################################

# Layer7 - Output Layer with softmax activation
model_2.add(layers.Dense(10, activation='softmax'))

# Compile the model
model_2.compile(loss=keras.losses.categorical_crossentropy, optimizer='adam', metrics=['accuracy'])

# Train
hist_2 = model_2.fit(x_train, y_train, validation_data=(x_test,y_test), batch_size=batch_size, epochs=epoch)

# Evaluate
# score_2 = model_2.evaluate(x_test, y_test, batch_size=batch_size)

# %% [markdown]
# ### > Plot Model

# %%
import matplotlib.pyplot as plt_2

plt_2.plot(hist_2.history['acc'])
plt_2.plot(hist_2.history['val_acc'])
plt_2.title('Model accuracy')
plt_2.ylabel('accuracy')
plt_2.xlabel('epoch')
#plt_2.legend(['Train, Validation'], loc=0)
plt_2.legend(['Train', 'Test'])
plt_2.show()

# %% [markdown]
# ### > Save Model

# %%
# if we want to save the model for later use we whould run this code block:
model_2.save("/GoogleDrive/My Drive/ex1_0330342797_038628343/model_2.h5")

# %% [markdown]
# # Lenet 5 - Weight Decay

# %% [markdown]
# ### > Load Exsisting Model

# %%
# this block should be run only if we want to load a saved models and use it (instead or fitting the model again):
from keras.models import Sequential
from keras import models, layers
import keras
from keras.models import load_model

model_3 = load_model('/GoogleDrive/My Drive/ex1_0330342797_038628343/model_3.h5')

# now we can use the model our model for example:
batch_size = 128
score_3 = model_3.evaluate(x_test, y_test, batch_size=batch_size)


print (score_3)

# %% [markdown]
# ### > Train Model

# %%
from keras.models import Sequential
from keras import models, layers
import keras
from keras import regularizers

# More Params
batch_size = 128
epoch = 10

# Instantiate an empty model
model_3 = Sequential()

# Layer1 - Convolutional Layer
model_3.add(layers.Conv2D(6, kernel_size=(5, 5), strides=(1, 1), activation='relu', input_shape=(28,28,1), padding='same'))

# Layer2 - Pooling Layer
model_3.add(layers.AveragePooling2D(pool_size=(2, 2), strides=(1, 1), padding='valid'))

# Layer3 - Convolutional Layer
model_3.add(layers.Conv2D(16, kernel_size=(5, 5), strides=(1, 1), activation='relu', padding='valid'))

# Layer4 - Pooling Layer
model_3.add(layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

# Layer5 - Fully Connected Convolutional Layer
model_3.add(layers.Conv2D(120, kernel_size=(5, 5), strides=(1, 1), activation='relu', padding='valid'))

# Flatten the CNN output so that we can connect it with fully connected layers
model_3.add(layers.Flatten())

# Layer6 -  Fully Connected Layer
model_3.add(layers.Dense(84, activation='relu', kernel_regularizer=regularizers.l2(0.01)))

# Layer7 - Output Layer with softmax activation
model_3.add(layers.Dense(10, activation='softmax'))

#####
# adam1 = keras.optimizers.Adam(lr=0.0011, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.001, amsgrad=False)
# model_3.compile(loss=keras.losses.categorical_crossentropy, optimizer=adam1, metrics=['accuracy'])
#####

# Compile the model
model_3.compile(loss=keras.losses.categorical_crossentropy, optimizer='adam', metrics=['accuracy'])

# Train
hist_3 = model_3.fit(x_train, y_train, validation_data=(x_test,y_test), batch_size=batch_size, epochs=epoch)

# Evaluate
# score_3 = model_3.evaluate(x_test, y_test, batch_size=batch_size)

# %% [markdown]
# ### > Plot Model

# %%
import matplotlib.pyplot as plt_3

plt_3.plot(hist_3.history['acc'])
plt_3.plot(hist_3.history['val_acc'])
plt_3.title('Model accuracy')
plt_3.ylabel('accuracy')
plt_3.xlabel('epoch')
#plt_3.legend(['Train, Validation'], loc=0)
plt_3.legend(['Train', 'Test'])
plt_3.show()

# %% [markdown]
# ### > Save Model

# %%
# if we want to save the model for later use we whould run this code block:
model_3.save("/GoogleDrive/My Drive/ex1_0330342797_038628343/model_3.h5")

# %% [markdown]
# # Lenet 5 - Batch Normalization

# %% [markdown]
# ### > Load Exsisting Model

# %%
# this block should be run only if we want to load a saved models and use it (instead or fitting the model again):
from keras.models import Sequential
from keras import models, layers
import keras
from keras.models import load_model

model_4 = load_model('/GoogleDrive/My Drive/ex1_0330342797_038628343/model_4.h5')

# now we can use the model our model for example:
batch_size = 128
score_4 = model_4.evaluate(x_test, y_test, batch_size=batch_size)


print (score_4)

# %% [markdown]
# ### > Train Model

# %%
from keras.models import Sequential
from keras import models, layers
import keras

# More Params
batch_size = 128
epoch = 10

# Instantiate an empty model
model_4 = Sequential()

# Layer1 - Convolutional Layer
model_4.add(layers.Conv2D(6, kernel_size=(5, 5), strides=(1, 1), activation='relu', input_shape=(28,28,1), padding='same'))

# Layer2 - Pooling Layer
model_4.add(layers.AveragePooling2D(pool_size=(2, 2), strides=(1, 1), padding='valid'))

## ADD BATCH NORM LAYER ##
 #model_4.add(layers.BatchNormalization(axis=-1, momentum=0.6))
model_4.add(layers.BatchNormalization())
##

# Layer3 - Convolutional Layer
model_4.add(layers.Conv2D(16, kernel_size=(5, 5), strides=(1, 1), activation='relu', padding='valid'))

# Layer4 - Pooling Layer
model_4.add(layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

# Layer5 - Fully Connected Convolutional Layer
model_4.add(layers.Conv2D(120, kernel_size=(5, 5), strides=(1, 1), activation='relu', padding='valid'))

# Flatten the CNN output so that we can connect it with fully connected layers
model_4.add(layers.Flatten())

# Layer6 -  Fully Connected Layer
model_4.add(layers.Dense(84, activation='relu'))

# Layer7 - Output Layer with softmax activation
model_4.add(layers.Dense(10, activation='softmax'))

# Compile the model
model_4.compile(loss=keras.losses.categorical_crossentropy, optimizer='adam', metrics=['accuracy'])

# Train
hist_4 = model_4.fit(x_train, y_train, batch_size=batch_size, epochs=epoch, validation_data=(x_test,y_test))

# Evaluate
#score_4 = model_4.evaluate(x_test, y_test, batch_size=batch_size)

# %% [markdown]
# ### > Plot Model

# %%
import matplotlib.pyplot as plt_4

plt_4.plot(hist_4.history['acc'])
plt_4.plot(hist_4.history['val_acc'])
plt_4.title('Model accuracy')
plt_4.ylabel('accuracy')
plt_4.xlabel('epoch')
plt_4.legend(['Train', 'Test'])
plt_4.show()

# %% [markdown]
# ### > Save Model

# %%
# if we want to save the model for later use we whould run this code block:
model_4.save("/GoogleDrive/My Drive/ex1_0330342797_038628343/model_4.h5")
